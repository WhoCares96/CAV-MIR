# %% [markdown]
# ### Prerequisites

# %%
import dotenv

dotenv.load_dotenv()
# Out:
# True

# %%
project_name = "language_pt"
encoder_id = "mert_v1_95m"

# data preparation
target_column = "language"
target_positive_class = "pt"
train_val_split = 0.9

# training
epochs = 1000
batch_size = 128
learning_rate = 0.002
embedding_dim = 768
dropout_rate = 0.0

# %% [markdown]
# ### Prepare Data

# %%
import io
import os
from concurrent.futures import ThreadPoolExecutor

import numpy as np
import pandas as pd
import s3fs
from cavmir.training.dataset import TrainingSample, create_webdataset

s3 = s3fs.S3FileSystem(anon=False)

dataset_prefix = os.environ["DATASET_PREFIX"]
embedding_prefix = os.environ["EMBEDDING_PREFIX"]


def create_embedding_path(song_id: str) -> str:
    return os.path.join(embedding_prefix, encoder_id, f"{song_id}.{encoder_id}.npy")


def create_training_sample(
    row: pd.Series, target_column: str, target_positive_class: str
) -> TrainingSample:
    embedding_path = create_embedding_path(row.song_id)
    embedding = np.load(io.BytesIO(s3.cat(embedding_path)))[0]

    target = np.array(
        [1] if getattr(row, target_column) == target_positive_class else [0]
    )

    training_sample = TrainingSample(
        id=str(row.song_id),
        embedding=embedding,
        target=target,
    )

    training_sample.validate_attributes()

    return training_sample


def create_training_samples(dataset: pd.DataFrame) -> list[TrainingSample]:
    with ThreadPoolExecutor() as executor:
        return list(
            executor.map(
                lambda row: create_training_sample(
                    row, target_column, target_positive_class
                ),
                dataset.itertuples(),
            )
        )

# %%
df = pd.read_csv(os.path.join(dataset_prefix, f"train_dataset_{project_name}.csv"))
df = df.sample(frac=1, random_state=1).reset_index(drop=True)

df_train = df.iloc[: int(len(df) * train_val_split)]
df_val = df.iloc[int(len(df) * train_val_split) :]

df_test = pd.read_csv(os.path.join(dataset_prefix, f"test_dataset_{project_name}.csv"))

# %%
create_webdataset(
    create_training_samples(df_train),
    f"datasets/{encoder_id}_train_{project_name}.tar",
)

# %%
create_webdataset(
    create_training_samples(df_val),
    f"datasets/{encoder_id}_val_{project_name}.tar",
)

# %%
create_webdataset(
    create_training_samples(df_test),
    f"datasets/{encoder_id}_test_{project_name}.tar",
)

# %% [markdown]
# ### Training

# %%
import os

import numpy as np
import torch
from cavmir.training.dataset import create_dataloader_from_webdataset_path
from cavmir.training.fit import fit_cav_model
from cavmir.training.network import CAVNetwork

# %%
train_dataloader = create_dataloader_from_webdataset_path(
    f"datasets/{encoder_id}_train_{project_name}.tar", batch_size=batch_size
)

val_dataloader = create_dataloader_from_webdataset_path(
    f"datasets/{encoder_id}_val_{project_name}.tar", batch_size=batch_size
)

model = CAVNetwork(
    input_shape=embedding_dim,
    target_shape=1,
    dropout_rate=dropout_rate,
)
# Out:
# /home/arne/Documents/git/CAV-MIR/.venv/lib/python3.12/site-packages/webdataset/compat.py:389: UserWarning: WebDataset(shardshuffle=...) is None; set explicitly to False or a number
#   warnings.warn(

# %%
# %%time

fit_cav_model(
    model,
    train_dataloader,
    val_dataloader,
    f"trainings/{project_name}/",
    num_epochs=epochs,
    learning_rate=learning_rate,
)
# Out:
# Epoch 1/1000
# Epoch 1 Train Loss: 0.6991
# Epoch 1 Validation Loss: 0.6901
# Model saved to trainings/language_pt/state_dict.pth
# Epoch 2/1000
# Epoch 2 Train Loss: 0.6855
# Epoch 2 Validation Loss: 0.6977
# Epoch 3/1000
# Epoch 3 Train Loss: 0.6828
# Epoch 3 Validation Loss: 0.6917
# Epoch 4/1000
# Epoch 4 Train Loss: 0.6763
# Epoch 4 Validation Loss: 0.6803
# Model saved to trainings/language_pt/state_dict.pth
# Epoch 5/1000
# Epoch 5 Train Loss: 0.6691
# Epoch 5 Validation Loss: 0.6716
# Model saved to trainings/language_pt/state_dict.pth
# Epoch
# Model saved to trainings/language_pt/state_dict.pth
# Epoch 43/1000
# Epoch 43 Train Loss: 0.5357
# Epoch 43 Validation Loss: 0.6267
# Model saved to trainings/language_pt/state_dict.pth
# Epoch 44/1000
# Epoch 44 Train Loss: 0.5335
# Epoch 44 Validation Loss: 0.6266
# Model saved to trainings/language_pt/state_dict.pth
# Epoch 45/1000
# Epoch 45 Train Loss: 0.5313
# Epoch 45 Validation Loss: 0.6264
# Model saved to trainings/language_pt/state_dict.pth
# Epoch 46/1000
# Epoch 46 Train Loss: 0.5292
# Epoch 46 Validation Loss: 0.6262
# Model saved to trainings/language_pt/state_dict.pth
# Epoch 47/1000
# Epoch 47 Train Loss: 0.5270
# Epoch 47 Validation Loss: 0.6261
# Model saved to trainings/language_pt/state_dict.pth
# Epoch 48/1000
# Epoch 48 Train Loss: 0.5250
# Epoch 48 Validation Loss: 0.6259
# Model saved to trainings/language_pt/state_dict.pth
# Epoch 49/1000
# Epoch 49 Train Loss: 0.5229
# Epoch 49 Validation Loss: 0.6258
# Model saved to trainings/language_pt/state_dict.pth
# Epoch 50/1000
# Epoch 50 Train Loss: 0.5209
# Epoch 50 Validation Loss: 0.6257
# Model saved to trainings/language_pt/state_dict.pth
# Epoch 51/1000
# Epoch 51 Train Loss: 0.5189
# Epoch 51 Validation Loss: 0.6256
# Model saved to trainings/language_pt/state_dict.pth
# Epoch 52/1000
# Epoch 52 Train Loss: 0.5169
# Epoch 52 Validation Loss: 0.6255
# Model saved to trainings/language_pt/state_dict.pth
# Epoch 53/1000
# Epoch 53 Train Loss: 0.5150
# Epoch 53 Validation Loss: 0.6255
# Model saved to trainings/language_pt/state_dict.pth
# Epoch 54/1000
# Epoch 54 Train Loss: 0.5130
# Epoch 54 Validation Loss: 0.6254
# Model saved to trainings/language_pt/state_dict.pth
# Epoch 55/1000
# Epoch 55 Train Loss: 0.5111
# Epoch 55 Validation Loss: 0.6253
# Model saved to trainings/language_pt/state_dict.pth
# Epoch 56/1000
# Epoch 56 Train Loss: 0.5092
# Epoch 56 Validation Loss: 0.6253
# Model saved to trainings/language_pt/state_dict.pth
# Epoch 57/1000
# Epoch 57 Train Loss: 0.5074
# Epoch 57 Validation Loss: 0.6252
# Model saved to trainings/language_pt/state_dict.pth
# Epoch 58/1000
# Epoch 58 Train Loss: 0.5056
# Epoch 58 Validation Loss: 0.6252
# Model saved to trainings/language_pt/state_dict.pth
# Epoch 59/1000
# Epoch 59 Train Loss: 0.5037
# Epoch 59 Validation Loss: 0.6252
# Model saved to trainings/language_pt/state_dict.pth
# Epoch 60/1000
# Epoch 60 Train Loss: 0.5020
# Epoch 60 Validation Loss: 0.6252
# Model saved to trainings/language_pt/state_dict.pth
# Epoch 61/1000
# Epoch 61 Train Loss: 0.5002
# Epoch 61 Validation Loss: 0.6252
# Model saved to trainings/language_pt/state_dict.pth
# Epoch 62/1000
# Epoch 62 Train Loss: 0.4984
# Epoch 62 Validation Loss: 0.6252
# Model saved to trainings/language_pt/state_dict.pth
# Epoch 63/1000
# Epoch 63 Train Loss: 0.4971
# Epoch 63 Validation Loss: 0.6252
# Epoch 64/1000
# Epoch 64 Train Loss: 0.4969
# Epoch 64 Validation Loss: 0.6252
# Epoch 65/1000
# Epoch 65 Train Loss: 0.4967
# Epoch 65 Validation Loss: 0.6252
# Epoch 66/1000
# Epoch 66 Train Loss: 0.4966
# Epoch 66 Validation Loss: 0.6252
# Epoch 67/1000
# Epoch 67 Train Loss: 0.4964
# Epoch 67 Validation Loss: 0.6252
# Early stopping at epoch 67
# Loss history saved to trainings/language_pt/loss_history.json
# CPU times: user 640 ms, sys: 3.24 s, total: 3.88 s
# Wall time: 19.3 s

# %%
model.load_state_dict(
    torch.load(
        os.path.join(
            "trainings",
            project_name,
            "state_dict.pth",
        )
    )
)

cav_vector = model.get_concept_activation_vector()


np.save(
    os.path.join(
        "trainings",
        project_name,
        f"cav_{project_name}.npy",
    ),
    cav_vector,
)

# %% [markdown]
# ### Evaluation

# %%
import json

import matplotlib.pyplot as plt
from cavmir.training.evaluate import evaluate_cav_model

# %%
loss_history = json.load(open(f"trainings/{project_name}/loss_history.json"))

plt.plot(loss_history["train_loss"], label="train")
plt.plot(loss_history["val_loss"], label="val")
plt.legend()
plt.grid()
plt.show()

# %%
test_dataloader = create_dataloader_from_webdataset_path(
    f"datasets/{encoder_id}_test_{project_name}.tar", batch_size=batch_size
)

evaluate_cav_model(model, test_dataloader, target_positive_class)
# Out:
# {'precision': 0.5328282828282829,
#  'recall': 0.5702702702702702,
#  'f1_score': 0.5509138381201044,
#  'accuracy': 0.5351351351351351}
