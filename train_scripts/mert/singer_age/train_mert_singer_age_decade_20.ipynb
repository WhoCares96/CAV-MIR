# %% [markdown]
# ### Prerequisites

# %%
import dotenv

dotenv.load_dotenv()
# Out:
# True

# %%
project_name = "singer_age_decade_20"
encoder_id = "mert_v1_95m"

# data preparation
target_column = "singer_age_decade"
target_positive_class = 20
train_val_split = 0.9


# training
epochs = 1000
batch_size = 128
learning_rate = 0.002
embedding_dim = 768
dropout_rate = 0.0

# %% [markdown]
# ### Prepare Data

# %%
import io
import os
from concurrent.futures import ThreadPoolExecutor

import numpy as np
import pandas as pd
import s3fs
from cavmir.training.dataset import TrainingSample, create_webdataset

s3 = s3fs.S3FileSystem(anon=False)

dataset_prefix = os.environ["DATASET_PREFIX"]
embedding_prefix = os.environ["EMBEDDING_PREFIX"]


def create_embedding_path(song_id: str) -> str:
    return os.path.join(embedding_prefix, encoder_id, f"{song_id}.{encoder_id}.npy")


def create_training_sample(
    row: pd.Series, target_column: str, target_positive_class: str
) -> TrainingSample:
    embedding_path = create_embedding_path(row.song_id)
    embedding = np.load(io.BytesIO(s3.cat(embedding_path)))[0]

    target = np.array(
        [1] if getattr(row, target_column) == target_positive_class else [0]
    )

    training_sample = TrainingSample(
        id=str(row.song_id),
        embedding=embedding,
        target=target,
    )

    training_sample.validate_attributes()

    return training_sample


def create_training_samples(dataset: pd.DataFrame) -> list[TrainingSample]:
    with ThreadPoolExecutor() as executor:
        return list(
            executor.map(
                lambda row: create_training_sample(
                    row, target_column, target_positive_class
                ),
                dataset.itertuples(),
            )
        )

# %%
df = pd.read_csv(os.path.join(dataset_prefix, f"train_dataset_{project_name}.csv"))
df = df.sample(frac=1, random_state=1).reset_index(drop=True)

df_train = df.iloc[: int(len(df) * train_val_split)]
df_val = df.iloc[int(len(df) * train_val_split) :]

df_test = pd.read_csv(os.path.join(dataset_prefix, f"test_dataset_{project_name}.csv"))

# %%
create_webdataset(
    create_training_samples(df_train),
    f"datasets/{encoder_id}_train_{project_name}.tar",
)

# %%
create_webdataset(
    create_training_samples(df_val),
    f"datasets/{encoder_id}_val_{project_name}.tar",
)

# %%
create_webdataset(
    create_training_samples(df_test),
    f"datasets/{encoder_id}_test_{project_name}.tar",
)

# %% [markdown]
# ### Training

# %%
import os

import numpy as np
import torch
from cavmir.training.dataset import create_dataloader_from_webdataset_path
from cavmir.training.fit import fit_cav_model
from cavmir.training.network import CAVNetwork

# %%
train_dataloader = create_dataloader_from_webdataset_path(
    f"datasets/{encoder_id}_train_{project_name}.tar", batch_size=batch_size
)

val_dataloader = create_dataloader_from_webdataset_path(
    f"datasets/{encoder_id}_val_{project_name}.tar", batch_size=batch_size
)

model = CAVNetwork(
    input_shape=embedding_dim,
    target_shape=1,
    dropout_rate=dropout_rate,
)
# Out:
# /home/arne/Documents/git/CAV-MIR/.venv/lib/python3.12/site-packages/webdataset/compat.py:389: UserWarning: WebDataset(shardshuffle=...) is None; set explicitly to False or a number
#   warnings.warn(

# %%
# %%time

fit_cav_model(
    model,
    train_dataloader,
    val_dataloader,
    f"trainings/{project_name}/",
    num_epochs=epochs,
    learning_rate=learning_rate,
)
# Out:
# Epoch 1/1000
# Epoch 1 Train Loss: 0.6832
# Epoch 1 Validation Loss: 0.6788
# Model saved to trainings/singer_age_decade_20/state_dict.pth
# Epoch 2/1000
# Epoch 2 Train Loss: 0.6671
# Epoch 2 Validation Loss: 0.6716
# Model saved to trainings/singer_age_decade_20/state_dict.pth
# Epoch 3/1000
# Epoch 3 Train Loss: 0.6590
# Epoch 3 Validation Loss: 0.6670
# Model saved to trainings/singer_age_decade_20/state_dict.pth
# Epoch 4/1000
# Epoch 4 Train Loss: 0.6535
# Epoch 4 Validation Loss: 0.6640
# Model saved to trainings/singer_age_decade_20/state_dict.pth
# Epoch 5/1000
# Epoch 5 Train Loss: 0.6495
# Epoch 5 Validation Loss: 0.6618
# Model saved to trainings/singer_age_decade_20/state_dict.pth
# Epoch 6/1000
# Epoch 6 Train Loss: 0.6462
# Epoch 6 Validation Loss: 0.6602
# Model saved to trainings/singer_age_decade_20/state_dict.pth
# Epoch 7/1000
# Epoch 7 Train Loss: 0.6436
# Epoch 7 Validation Loss: 0.6589
# Model saved to trainings/singer_age_decade_20/state_dict.pth
# Epoch 8/1000
# Epoch 8 Train Loss: 0.6413
# Epoch 8 Validation Loss: 0.6578
# Model saved to trainings/singer_age_decade_20/state_dict.pth
# Epoch 9/1000
# Epoch 9 Train Loss: 0.6394
# Epoch 9 Validation Loss: 0.6570
# Model saved to trainings/singer_age_decade_20/state_dict.pth
# Epoch 10/1000
# Epoch 10 Train Loss: 0.6376
# Epoch 10 Validation Loss: 0.6563
# Model saved to trainings/singer_age_decade_20/state_dict.pth
# Epoch 11/1000
# Epoch 11 Train Loss: 0.6361
# Epoch 11 Validation Loss: 0.6558
# Model saved to trainings/singer_age_decade_20/state_dict.pth
# Epoch 12/1000
# Epoch 12 Train Loss: 0.6347
# Epoch 12 Validation Loss: 0.6553
# Model saved to trainings/singer_age_decade_20/state_dict.pth
# Epoch 13/1000
# Epoch 13 Train Loss: 0.6334
# Epoch 13 Validation Loss: 0.6550
# Model saved to trainings/singer_age_decade_20/state_dict.pth
# Epoch 14/1000
# Epoch 14 Train Loss: 0.6322
# Epoch 14 Validation Loss: 0.6547
# Model saved to trainings/singer_age_decade_20/state_dict.pth
# Epoch 15/1000
# Epoch 15 Train Loss: 0.6311
# Epoch 15 Validation Loss: 0.6545
# Model saved to trainings/singer_age_decade_20/state_dict.pth
# Epoch 16/1000
# Epoch 16 Train Loss: 0.6301
# Epoch 16 Validation Loss: 0.6543
# Model saved to trainings/singer_age_decade_20/state_dict.pth
# Epoch 17/1000
# Epoch 17 Train Loss: 0.6291
# Epoch 17 Validation Loss: 0.6541
# Model saved to trainings/singer_age_decade_20/state_dict.pth
# Epoch 18/1000
# Epoch 18 Train Loss: 0.6283
# Epoch 18 Validation Loss: 0.6540
# Model saved to trainings/singer_age_decade_20/state_dict.pth
# Epoch 19/1000
# Epoch 19 Train Loss: 0.6274
# Epoch 19 Validation Loss: 0.6539
# Model saved to trainings/singer_age_decade_20/state_dict.pth
# Epoch 20/1000
# Epoch 20 Train Loss: 0.6266
# Epoch 20 Validation Loss: 0.6539
# Model saved to trainings/singer_age_decade_20/state_dict.pth
# Epoch 21/1000
# Epoch 21 Train Loss: 0.6259
# Epoch 21 Validation Loss: 0.6538
# Model saved to trainings/singer_age_decade_20/state_dict.pth
# Epoch 22/1000
# Epoch 22 Train Loss: 0.6252
# Epoch 22 Validation Loss: 0.6538
# Model saved to trainings/singer_age_decade_20/state_dict.pth
# Epoch 23/1000
# Epoch 23 Train Loss: 0.6245
# Epoch 23 Validation Loss: 0.6538
# Model saved to trainings/singer_age_decade_20/state_dict.pth
# Epoch 24/1000
# Epoch 24 Train Loss: 0.6238
# Epoch 24 Validation Loss: 0.6538
# Epoch 25/1000
# Epoch 25 Train Loss: 0.6232
# Epoch 25 Validation Loss: 0.6538
# Epoch 26/1000
# Epoch 26 Train Loss: 0.6210
# Epoch 26 Validation Loss: 0.6531
# Model saved to trainings/singer_age_decade_20/state_dict.pth
# Epoch 27/1000
# Epoch 27 Train Loss: 0.6208
# Epoch 27 Validation Loss: 0.6531
# Epoch 28/1000
# Epoch 28 Train Loss: 0.6207
# Epoch 28 Validation Loss: 0.6531
# Epoch 29/1000
# Epoch 29 Train Loss: 0.6207
# Epoch 29 Validation Loss: 0.6531
# Epoch 30/1000
# Epoch 30 Train Loss: 0.6206
# Epoch 30 Validation Loss: 0.6532
# Epoch 31/1000
# Epoch 31 Train Loss: 0.6204
# Epoch 31 Validation Loss: 0.6530
# Model saved to trainings/singer_age_decade_20/state_dict.pth
# Epoch 32/1000
# Epoch 32 Train Loss: 0.6204
# Epoch 32 Validation Loss: 0.6529
# Model saved to trainings/singer_age_decade_20/state_dict.pth
# Epoch 33/1000
# Epoch 33 Train Loss: 0.6203
# Epoch 33 Validation Loss: 0.6528
# Model saved to trainings/singer_age_decade_20/state_dict.pth
# Epoch 34/1000
# Epoch 34 Train Loss: 0.6203
# Epoch 34 Validation Loss: 0.6527
# Model saved to trainings/singer_age_decade_20/state_dict.pth
# Epoch 35/1000
# Epoch 35 Train Loss: 0.6203
# Epoch 35 Validation Loss: 0.6527
# Model saved to trainings/singer_age_decade_20/state_dict.pth
# Epoch 36/1000
# Epoch 36 Train Loss: 0.6203
# Epoch 36 Validation Loss: 0.6527
# Model saved to trainings/singer_age_decade_20/state_dict.pth
# Epoch 37/1000
# Epoch 37 Train Loss: 0.6203
# Epoch 37 Validation Loss: 0.6527
# Model saved to trainings/singer_age_decade_20/state_dict.pth
# Epoch 38/1000
# Epoch 38 Train Loss: 0.6203
# Epoch 38 Validation Loss: 0.6527
# Model saved to trainings/singer_age_decade_20/state_dict.pth
# Epoch 39/1000
# Epoch 39 Train Loss: 0.6203
# Epoch 39 Validation Loss: 0.6527
# Model saved to trainings/singer_age_decade_20/state_dict.pth
# Epoch 40/1000
# Epoch 40 Train Loss: 0.6202
# Epoch 40 Validation Loss: 0.6527
# Model saved to trainings/singer_age_decade_20/state_dict.pth
# Epoch 41/1000
# Epoch 41 Train Loss: 0.6202
# Epoch 41 Validation Loss: 0.6527
# Model saved to trainings/singer_age_decade_20/state_dict.pth
# Epoch 42/1000
# Epoch 42 Train Loss: 0.6202
# Epoch 42 Validation Loss: 0.6527
# Model saved to trainings/singer_age_decade_20/state_dict.pth
# Epoch 43/1000
# Epoch 43 Train Loss: 0.6202
# Epoch 43 Validation Loss: 0.6527
# Model saved to trainings/singer_age_decade_20/state_dict.pth
# Epoch 44/1000
# Epoch 44 Train Loss: 0.6202
# Epoch 44 Validation Loss: 0.6527
# Model saved to trainings/singer_age_decade_20/state_dict.pth
# Epoch 45/1000
# Epoch 45 Train Loss: 0.6202
# Epoch 45 Validation Loss: 0.6527
# Model saved to trainings/singer_age_decade_20/state_dict.pth
# Epoch 46/1000
# Epoch 46 Train Loss: 0.6202
# Epoch 46 Validation Loss: 0.6527
# Model saved to trainings/singer_age_decade_20/state_dict.pth
# Epoch 47/1000
# Epoch 47 Train Loss: 0.6202
# Epoch 47 Validation Loss: 0.6527
# Model saved to trainings/singer_age_decade_20/state_dict.pth
# Epoch 48/1000
# Epoch 48 Train Loss: 0.6202
# Epoch 48 Validation Loss: 0.6527
# Epoch 49/1000
# Epoch 49 Train Loss: 0.6202
# Epoch 49 Validation Loss: 0.6527
# Model saved to trainings/singer_age_decade_20/state_dict.pth
# Epoch 50/1000
# Epoch 50 Train Loss: 0.6202
# Epoch 50 Validation Loss: 0.6527
# Epoch 51/1000
# Epoch 51 Train Loss: 0.6202
# Epoch 51 Validation Loss: 0.6527
# Model saved to trainings/singer_age_decade_20/state_dict.pth
# Epoch 52/1000
# Epoch 52 Train Loss: 0.6202
# Epoch 52 Validation Loss: 0.6527
# Model saved to trainings/singer_age_decade_20/state_dict.pth
# Epoch 53/1000
# Epoch 53 Train Loss: 0.6202
# Epoch 53 Validation Loss: 0.6527
# Epoch 54/1000
# Epoch 54 Train Loss: 0.6202
# Epoch 54 Validation Loss: 0.6527
# Epoch 55/1000
# Epoch 55 Train Loss: 0.6202
# Epoch 55 Validation Loss: 0.6527
# Epoch 56/1000
# Epoch 56 Train Loss: 0.6202
# Epoch 56 Validation Loss: 0.6527
# Epoch 57/1000
# Epoch 57 Train Loss: 0.6202
# Epoch 57 Validation Loss: 0.6527
# Early stopping at epoch 57
# Loss history saved to trainings/singer_age_decade_20/loss_history.json
# CPU times: user 12.4 s, sys: 6.93 s, total: 19.3 s
# Wall time: 3min 14s

# %%
model.load_state_dict(
    torch.load(
        os.path.join(
            "trainings",
            project_name,
            "state_dict.pth",
        )
    )
)

cav_vector = model.get_concept_activation_vector()


np.save(
    os.path.join(
        "trainings",
        project_name,
        f"cav_{project_name}.npy",
    ),
    cav_vector,
)

# %% [markdown]
# ### Evaluation

# %%
import json

import matplotlib.pyplot as plt
from cavmir.training.evaluate import evaluate_cav_model

# %%
loss_history = json.load(open(f"trainings/{project_name}/loss_history.json"))

plt.plot(loss_history["train_loss"], label="train")
plt.plot(loss_history["val_loss"], label="val")
plt.legend()
plt.grid()
plt.show()

# %%
test_dataloader = create_dataloader_from_webdataset_path(
    f"datasets/{encoder_id}_test_{project_name}.tar", batch_size=batch_size
)

evaluate_cav_model(model, test_dataloader, target_positive_class)
# Out:
# /home/arne/Documents/git/CAV-MIR/.venv/lib/python3.12/site-packages/webdataset/compat.py:389: UserWarning: WebDataset(shardshuffle=...) is None; set explicitly to False or a number
#   warnings.warn(
# {'precision': 0.6237885462555066,
#  'recall': 0.589018302828619,
#  'f1_score': 0.6059050064184852,
#  'accuracy': 0.6168885191347754}
