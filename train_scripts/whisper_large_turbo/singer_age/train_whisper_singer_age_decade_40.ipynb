# %% [markdown]
# ### Prerequisites

# %%
import dotenv

dotenv.load_dotenv()
# Out:
# True

# %%
project_name = "singer_age_decade_40"
encoder_id = "whisper_large_turbo"

# data preparation
target_column = "singer_age_decade"
target_positive_class = 40
train_val_split = 0.9


# training
epochs = 1000
batch_size = 128
learning_rate = 0.002
embedding_dim = 1280
dropout_rate = 0.0

# %% [markdown]
# ### Prepare Data

# %%
import io
import os
from concurrent.futures import ThreadPoolExecutor

import numpy as np
import pandas as pd
import s3fs
from cavmir.training.dataset import TrainingSample, create_webdataset

s3 = s3fs.S3FileSystem(anon=False)

dataset_prefix = os.environ["DATASET_PREFIX"]
embedding_prefix = os.environ["EMBEDDING_PREFIX"]


def create_embedding_path(song_id: str) -> str:
    return os.path.join(embedding_prefix, encoder_id, f"{song_id}.{encoder_id}.npy")


def create_training_sample(
    row: pd.Series, target_column: str, target_positive_class: str
) -> TrainingSample:
    embedding_path = create_embedding_path(row.song_id)
    embedding = np.load(io.BytesIO(s3.cat(embedding_path)))[0]

    target = np.array(
        [1] if getattr(row, target_column) == target_positive_class else [0]
    )

    training_sample = TrainingSample(
        id=str(row.song_id),
        embedding=embedding,
        target=target,
    )

    training_sample.validate_attributes()

    return training_sample


def create_training_samples(dataset: pd.DataFrame) -> list[TrainingSample]:
    with ThreadPoolExecutor() as executor:
        return list(
            executor.map(
                lambda row: create_training_sample(
                    row, target_column, target_positive_class
                ),
                dataset.itertuples(),
            )
        )

# %%
df = pd.read_csv(os.path.join(dataset_prefix, f"train_dataset_{project_name}.csv"))
df = df.sample(frac=1, random_state=1).reset_index(drop=True)

df_train = df.iloc[: int(len(df) * train_val_split)]
df_val = df.iloc[int(len(df) * train_val_split) :]

df_test = pd.read_csv(os.path.join(dataset_prefix, f"test_dataset_{project_name}.csv"))

# %%
create_webdataset(
    create_training_samples(df_train),
    f"datasets/{encoder_id}_train_{project_name}.tar",
)

# %%
create_webdataset(
    create_training_samples(df_val),
    f"datasets/{encoder_id}_val_{project_name}.tar",
)

# %%
create_webdataset(
    create_training_samples(df_test),
    f"datasets/{encoder_id}_test_{project_name}.tar",
)

# %% [markdown]
# ### Training

# %%
import os

import numpy as np
import torch
from cavmir.training.dataset import create_dataloader_from_webdataset_path
from cavmir.training.fit import fit_cav_model
from cavmir.training.network import CAVNetwork

# %%
train_dataloader = create_dataloader_from_webdataset_path(
    f"datasets/{encoder_id}_train_{project_name}.tar", batch_size=batch_size
)

val_dataloader = create_dataloader_from_webdataset_path(
    f"datasets/{encoder_id}_val_{project_name}.tar", batch_size=batch_size
)

model = CAVNetwork(
    input_shape=embedding_dim,
    target_shape=1,
    dropout_rate=dropout_rate,
)
# Out:
# /home/arne/Documents/git/CAV-MIR/.venv/lib/python3.12/site-packages/webdataset/compat.py:389: UserWarning: WebDataset(shardshuffle=...) is None; set explicitly to False or a number
#   warnings.warn(

# %%
# %%time

fit_cav_model(
    model,
    train_dataloader,
    val_dataloader,
    f"trainings/{project_name}/",
    num_epochs=epochs,
    learning_rate=learning_rate,
)
# Out:
# Epoch 1/1000
# Epoch 1 Train Loss: 0.6920
# Epoch 1 Validation Loss: 0.6836
# Model saved to trainings/singer_age_decade_40/state_dict.pth
# Epoch 2/1000
# Epoch 2 Train Loss: 0.6837
# Epoch 2 Validation Loss: 0.6796
# Model saved to trainings/singer_age_decade_40/state_dict.pth
# Epoch 3/1000
# Epoch 3 Train Loss: 0.6782
# Epoch 3 Validation Loss: 0.6764
# Model saved to trainings/singer_age_decade_40/state_dict.pth
# Epoch 4/1000
# Epoch 4 Train Loss: 0.6735
# Epoch 4 Validation Loss: 0.6729
# Model saved to trainings/singer_age_decade_40/state_dict.pth
# Epoch 5/1000
# Epoch 5 Train Loss: 0.6697
# Epoch 5 Validation Loss: 0.6704
# Model saved to trainings/singer_age_decade_40/state_dict.pth
# Epoch 6/1000
# Epoch 6 Train Loss: 0.6662
# Epoch 6 Validation Loss: 0.6681
# Model saved to trainings/singer_age_decade_40/state_dict.pth
# Epoch 7/1000
# Epoch 7 Train Loss: 0.6631
# Epoch 7 Validation Loss: 0.6661
# Model saved to trainings/singer_age_decade_40/state_dict.pth
# Epoch 8/1000
# Epoch 8 Train Loss: 0.6602
# Epoch 8 Validation Loss: 0.6645
# Model saved to trainings/singer_age_decade_40/state_dict.pth
# Epoch 9/1000
# Epoch 9 Train Loss: 0.6576
# Epoch 9 Validation Loss: 0.6632
# Model saved to trainings/singer_age_decade_40/state_dict.pth
# Epoch 10/1000
# Epoch 10 Train Loss: 0.6552
# Epoch 10 Validation Loss: 0.6621
# Model saved to trainings/singer_age_decade_40/state_dict.pth
# Epoch 11/1000
# Epoch 11 Train Loss: 0.6530
# Epoch 11 Validation Loss: 0.6611
# Model saved to trainings/singer_age_decade_40/state_dict.pth
# Epoch 12/1000
# Epoch 12 Train Loss: 0.6509
# Epoch 12 Validation Loss: 0.6603
# Model saved to trainings/singer_age_decade_40/state_dict.pth
# Epoch 13/1000
# Epoch 13 Train Loss: 0.6489
# Epoch 13 Validation Loss: 0.6597
# Model saved to trainings/singer_age_decade_40/state_dict.pth
# Epoch 14/1000
# Epoch 14 Train Loss: 0.6470
# Epoch 14 Validation Loss: 0.6592
# Model saved to trainings/singer_age_decade_40/state_dict.pth
# Epoch 15/1000
# Epoch 15 Train Loss: 0.6452
# Epoch 15 Validation Loss: 0.6587
# Model saved to trainings/singer_age_decade_40/state_dict.pth
# Epoch 16/1000
# Epoch 16 Train Loss: 0.6435
# Epoch 16 Validation Loss: 0.6583
# Model saved to trainings/singer_age_decade_40/state_dict.pth
# Epoch 17/1000
# Epoch 17 Train Loss: 0.6419
# Epoch 17 Validation Loss: 0.6580
# Model saved to trainings/singer_age_decade_40/state_dict.pth
# Epoch 18/1000
# Epoch 18 Train Loss: 0.6403
# Epoch 18 Validation Loss: 0.6578
# Model saved to trainings/singer_age_decade_40/state_dict.pth
# Epoch 19/1000
# Epoch 19 Train Loss: 0.6388
# Epoch 19 Validation Loss: 0.6576
# Model saved to trainings/singer_age_decade_40/state_dict.pth
# Epoch 20/1000
# Epoch 20 Train Loss: 0.6374
# Epoch 20 Validation Loss: 0.6575
# Model saved to trainings/singer_age_decade_40/state_dict.pth
# Epoch 21/1000
# Epoch 21 Train Loss: 0.6360
# Epoch 21 Validation Loss: 0.6573
# Model saved to trainings/singer_age_decade_40/state_dict.pth
# Epoch 22/1000
# Epoch 22 Train Loss: 0.6346
# Epoch 22 Validation Loss: 0.6573
# Model saved to trainings/singer_age_decade_40/state_dict.pth
# Epoch 23/1000
# Epoch 23 Train Loss: 0.6333
# Epoch 23 Validation Loss: 0.6572
# Model saved to trainings/singer_age_decade_40/state_dict.pth
# Epoch 24/1000
# Epoch 24 Train Loss: 0.6321
# Epoch 24 Validation Loss: 0.6572
# Model saved to trainings/singer_age_decade_40/state_dict.pth
# Epoch 25/1000
# Epoch 25 Train Loss: 0.6308
# Epoch 25 Validation Loss: 0.6571
# Model saved to trainings/singer_age_decade_40/state_dict.pth
# Epoch 26/1000
# Epoch 26 Train Loss: 0.6296
# Epoch 26 Validation Loss: 0.6572
# Epoch 27/1000
# Epoch 27 Train Loss: 0.6284
# Epoch 27 Validation Loss: 0.6572
# Epoch 28/1000
# Epoch 28 Train Loss: 0.6273
# Epoch 28 Validation Loss: 0.6572
# Epoch 29/1000
# Epoch 29 Train Loss: 0.6259
# Epoch 29 Validation Loss: 0.6572
# Epoch 30/1000
# Epoch 30 Train Loss: 0.6258
# Epoch 30 Validation Loss: 0.6572
# Early stopping at epoch 30
# Loss history saved to trainings/singer_age_decade_40/loss_history.json
# CPU times: user 2.64 s, sys: 2.87 s, total: 5.51 s
# Wall time: 44.4 s

# %%
model.load_state_dict(
    torch.load(
        os.path.join(
            "trainings",
            project_name,
            "state_dict.pth",
        )
    )
)

cav_vector = model.get_concept_activation_vector()


np.save(
    os.path.join(
        "trainings",
        project_name,
        f"cav_{project_name}.npy",
    ),
    cav_vector,
)

# %% [markdown]
# ### Evaluation

# %%
import json

import matplotlib.pyplot as plt
from cavmir.training.evaluate import evaluate_cav_model

# %%
loss_history = json.load(open(f"trainings/{project_name}/loss_history.json"))

plt.plot(loss_history["train_loss"], label="train")
plt.plot(loss_history["val_loss"], label="val")
plt.legend()
plt.grid()
plt.show()

# %%
test_dataloader = create_dataloader_from_webdataset_path(
    f"datasets/{encoder_id}_test_{project_name}.tar", batch_size=batch_size
)

evaluate_cav_model(model, test_dataloader, target_positive_class)
# Out:
# /home/arne/Documents/git/CAV-MIR/.venv/lib/python3.12/site-packages/webdataset/compat.py:389: UserWarning: WebDataset(shardshuffle=...) is None; set explicitly to False or a number
#   warnings.warn(
# {'precision': 0.580316742081448,
#  'recall': 0.5366108786610879,
#  'f1_score': 0.5576086956521739,
#  'accuracy': 0.5742677824267782}
