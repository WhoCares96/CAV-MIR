# %% [markdown]
# ### Prerequisites

# %%
import dotenv

dotenv.load_dotenv()
# Out:
# True

# %%
project_name = "singer_age_decade_20"
encoder_id = "whisper_large_v2"

# data preparation
target_column = "singer_age_decade"
target_positive_class = 20
train_val_split = 0.9


# training
epochs = 1000
batch_size = 128
learning_rate = 0.002
embedding_dim = 1280
dropout_rate = 0.0

# %% [markdown]
# ### Prepare Data

# %%
import io
import os
from concurrent.futures import ThreadPoolExecutor

import numpy as np
import pandas as pd
import s3fs
from cavmir.training.dataset import TrainingSample, create_webdataset

s3 = s3fs.S3FileSystem(anon=False)

dataset_prefix = os.environ["DATASET_PREFIX"]
embedding_prefix = os.environ["EMBEDDING_PREFIX"]


def create_embedding_path(song_id: str) -> str:
    return os.path.join(embedding_prefix, encoder_id, f"{song_id}.{encoder_id}.npy")


def create_training_sample(
    row: pd.Series, target_column: str, target_positive_class: str
) -> TrainingSample:
    embedding_path = create_embedding_path(row.song_id)
    embedding = np.load(io.BytesIO(s3.cat(embedding_path)))[0]

    target = np.array(
        [1] if getattr(row, target_column) == target_positive_class else [0]
    )

    training_sample = TrainingSample(
        id=str(row.song_id),
        embedding=embedding,
        target=target,
    )

    training_sample.validate_attributes()

    return training_sample


def create_training_samples(dataset: pd.DataFrame) -> list[TrainingSample]:
    with ThreadPoolExecutor() as executor:
        return list(
            executor.map(
                lambda row: create_training_sample(
                    row, target_column, target_positive_class
                ),
                dataset.itertuples(),
            )
        )

# %%
df = pd.read_csv(os.path.join(dataset_prefix, f"train_dataset_{project_name}.csv"))
df = df.sample(frac=1, random_state=1).reset_index(drop=True)

df_train = df.iloc[: int(len(df) * train_val_split)]
df_val = df.iloc[int(len(df) * train_val_split) :]

df_test = pd.read_csv(os.path.join(dataset_prefix, f"test_dataset_{project_name}.csv"))

# %%
create_webdataset(
    create_training_samples(df_train),
    f"datasets/{encoder_id}_train_{project_name}.tar",
)

# %%
create_webdataset(
    create_training_samples(df_val),
    f"datasets/{encoder_id}_val_{project_name}.tar",
)

# %%
create_webdataset(
    create_training_samples(df_test),
    f"datasets/{encoder_id}_test_{project_name}.tar",
)

# %% [markdown]
# ### Training

# %%
import os

import numpy as np
import torch
from cavmir.training.dataset import create_dataloader_from_webdataset_path
from cavmir.training.fit import fit_cav_model
from cavmir.training.network import CAVNetwork

# %%
train_dataloader = create_dataloader_from_webdataset_path(
    f"datasets/{encoder_id}_train_{project_name}.tar", batch_size=batch_size
)

val_dataloader = create_dataloader_from_webdataset_path(
    f"datasets/{encoder_id}_val_{project_name}.tar", batch_size=batch_size
)

model = CAVNetwork(
    input_shape=embedding_dim,
    target_shape=1,
    dropout_rate=dropout_rate,
)
# Out:
# /home/arne/Documents/git/CAV-MIR/.venv/lib/python3.12/site-packages/webdataset/compat.py:389: UserWarning: WebDataset(shardshuffle=...) is None; set explicitly to False or a number
#   warnings.warn(

# %%
# %%time

fit_cav_model(
    model,
    train_dataloader,
    val_dataloader,
    f"trainings/{project_name}/",
    num_epochs=epochs,
    learning_rate=learning_rate,
)
# Out:
# Epoch 1/1000
# Epoch 1 Train Loss: 0.6716
# Epoch 1 Validation Loss: 0.6611
# Model saved to trainings/singer_age_decade_20/state_dict.pth
# Epoch 2/1000
# Epoch 2 Train Loss: 0.6509
# Epoch 2 Validation Loss: 0.6455
# Model saved to trainings/singer_age_decade_20/state_dict.pth
# Epoch 3/1000
# Epoch 3 Train Loss: 0.6419
# Epoch 3 Validation Loss: 0.6363
# Model saved to trainings/singer_age_decade_20/state_dict.pth
# Epoch 4/1000
# Epoch 4 Train Loss: 0.6361
# Epoch 4 Validation Loss: 0.6302
# Model saved to trainings/singer_age_decade_20/state_dict.pth
# Epoch 5/1000
# Epoch 5 Train Loss: 0.6319
# Epoch 5 Validation Loss: 0.6258
# Model saved to trainings/singer_age_decade_20/state_dict.pth
# Epoch
# Model saved to trainings/singer_age_decade_20/state_dict.pth
# Epoch 136/1000
# Epoch 136 Train Loss: 0.5630
# Epoch 136 Validation Loss: 0.5893
# Model saved to trainings/singer_age_decade_20/state_dict.pth
# Epoch 137/1000
# Epoch 137 Train Loss: 0.5630
# Epoch 137 Validation Loss: 0.5893
# Model saved to trainings/singer_age_decade_20/state_dict.pth
# Epoch 138/1000
# Epoch 138 Train Loss: 0.5630
# Epoch 138 Validation Loss: 0.5893
# Model saved to trainings/singer_age_decade_20/state_dict.pth
# Epoch 139/1000
# Epoch 139 Train Loss: 0.5628
# Epoch 139 Validation Loss: 0.5892
# Model saved to trainings/singer_age_decade_20/state_dict.pth
# Epoch 140/1000
# Epoch 140 Train Loss: 0.5628
# Epoch 140 Validation Loss: 0.5892
# Model saved to trainings/singer_age_decade_20/state_dict.pth
# Epoch 141/1000
# Epoch 141 Train Loss: 0.5628
# Epoch 141 Validation Loss: 0.5892
# Model saved to trainings/singer_age_decade_20/state_dict.pth
# Epoch 142/1000
# Epoch 142 Train Loss: 0.5628
# Epoch 142 Validation Loss: 0.5892
# Model saved to trainings/singer_age_decade_20/state_dict.pth
# Epoch 143/1000
# Epoch 143 Train Loss: 0.5628
# Epoch 143 Validation Loss: 0.5892
# Model saved to trainings/singer_age_decade_20/state_dict.pth
# Epoch 144/1000
# Epoch 144 Train Loss: 0.5627
# Epoch 144 Validation Loss: 0.5892
# Model saved to trainings/singer_age_decade_20/state_dict.pth
# Epoch 145/1000
# Epoch 145 Train Loss: 0.5627
# Epoch 145 Validation Loss: 0.5892
# Model saved to trainings/singer_age_decade_20/state_dict.pth
# Epoch 146/1000
# Epoch 146 Train Loss: 0.5627
# Epoch 146 Validation Loss: 0.5892
# Model saved to trainings/singer_age_decade_20/state_dict.pth
# Epoch 147/1000
# Epoch 147 Train Loss: 0.5627
# Epoch 147 Validation Loss: 0.5892
# Model saved to trainings/singer_age_decade_20/state_dict.pth
# Epoch 148/1000
# Epoch 148 Train Loss: 0.5627
# Epoch 148 Validation Loss: 0.5892
# Model saved to trainings/singer_age_decade_20/state_dict.pth
# Epoch 149/1000
# Epoch 149 Train Loss: 0.5627
# Epoch 149 Validation Loss: 0.5892
# Model saved to trainings/singer_age_decade_20/state_dict.pth
# Epoch 150/1000
# Epoch 150 Train Loss: 0.5627
# Epoch 150 Validation Loss: 0.5892
# Model saved to trainings/singer_age_decade_20/state_dict.pth
# Epoch 151/1000
# Epoch 151 Train Loss: 0.5627
# Epoch 151 Validation Loss: 0.5892
# Model saved to trainings/singer_age_decade_20/state_dict.pth
# Epoch 152/1000
# Epoch 152 Train Loss: 0.5627
# Epoch 152 Validation Loss: 0.5892
# Model saved to trainings/singer_age_decade_20/state_dict.pth
# Epoch 153/1000
# Epoch 153 Train Loss: 0.5627
# Epoch 153 Validation Loss: 0.5892
# Epoch 154/1000
# Epoch 154 Train Loss: 0.5627
# Epoch 154 Validation Loss: 0.5892
# Epoch 155/1000
# Epoch 155 Train Loss: 0.5627
# Epoch 155 Validation Loss: 0.5892
# Epoch 156/1000
# Epoch 156 Train Loss: 0.5627
# Epoch 156 Validation Loss: 0.5892
# Epoch 157/1000
# Epoch 157 Train Loss: 0.5627
# Epoch 157 Validation Loss: 0.5892
# Early stopping at epoch 157
# Loss history saved to trainings/singer_age_decade_20/loss_history.json
# CPU times: user 30 s, sys: 21.4 s, total: 51.4 s
# Wall time: 10min 34s

# %%
model.load_state_dict(
    torch.load(
        os.path.join(
            "trainings",
            project_name,
            "state_dict.pth",
        )
    )
)

cav_vector = model.get_concept_activation_vector()


np.save(
    os.path.join(
        "trainings",
        project_name,
        f"cav_{project_name}.npy",
    ),
    cav_vector,
)

# %% [markdown]
# ### Evaluation

# %%
import json

import matplotlib.pyplot as plt
from cavmir.training.evaluate import evaluate_cav_model

# %%
loss_history = json.load(open(f"trainings/{project_name}/loss_history.json"))

plt.plot(loss_history["train_loss"], label="train")
plt.plot(loss_history["val_loss"], label="val")
plt.legend()
plt.grid()
plt.show()

# %%
test_dataloader = create_dataloader_from_webdataset_path(
    f"datasets/{encoder_id}_test_{project_name}.tar", batch_size=batch_size
)

evaluate_cav_model(model, test_dataloader, target_positive_class)
# Out:
# /home/arne/Documents/git/CAV-MIR/.venv/lib/python3.12/site-packages/webdataset/compat.py:389: UserWarning: WebDataset(shardshuffle=...) is None; set explicitly to False or a number
#   warnings.warn(
# {'precision': 0.6519097222222222,
#  'recall': 0.6247920133111481,
#  'f1_score': 0.6380628717077316,
#  'accuracy': 0.6455906821963394}
