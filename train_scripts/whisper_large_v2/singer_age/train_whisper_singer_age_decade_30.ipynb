# %% [markdown]
# ### Prerequisites

# %%
import dotenv

dotenv.load_dotenv()
# Out:
# True

# %%
project_name = "singer_age_decade_30"
encoder_id = "whisper_large_v2"

# data preparation
target_column = "singer_age_decade"
target_positive_class = 30
train_val_split = 0.9


# training
epochs = 1000
batch_size = 128
learning_rate = 0.002
embedding_dim = 1280
dropout_rate = 0.0

# %% [markdown]
# ### Prepare Data

# %%
import io
import os
from concurrent.futures import ThreadPoolExecutor

import numpy as np
import pandas as pd
import s3fs
from cavmir.training.dataset import TrainingSample, create_webdataset

s3 = s3fs.S3FileSystem(anon=False)

dataset_prefix = os.environ["DATASET_PREFIX"]
embedding_prefix = os.environ["EMBEDDING_PREFIX"]


def create_embedding_path(song_id: str) -> str:
    return os.path.join(embedding_prefix, encoder_id, f"{song_id}.{encoder_id}.npy")


def create_training_sample(
    row: pd.Series, target_column: str, target_positive_class: str
) -> TrainingSample:
    embedding_path = create_embedding_path(row.song_id)
    embedding = np.load(io.BytesIO(s3.cat(embedding_path)))[0]

    target = np.array(
        [1] if getattr(row, target_column) == target_positive_class else [0]
    )

    training_sample = TrainingSample(
        id=str(row.song_id),
        embedding=embedding,
        target=target,
    )

    training_sample.validate_attributes()

    return training_sample


def create_training_samples(dataset: pd.DataFrame) -> list[TrainingSample]:
    with ThreadPoolExecutor() as executor:
        return list(
            executor.map(
                lambda row: create_training_sample(
                    row, target_column, target_positive_class
                ),
                dataset.itertuples(),
            )
        )

# %%
df = pd.read_csv(os.path.join(dataset_prefix, f"train_dataset_{project_name}.csv"))
df = df.sample(frac=1, random_state=1).reset_index(drop=True)

df_train = df.iloc[: int(len(df) * train_val_split)]
df_val = df.iloc[int(len(df) * train_val_split) :]

df_test = pd.read_csv(os.path.join(dataset_prefix, f"test_dataset_{project_name}.csv"))

# %%
create_webdataset(
    create_training_samples(df_train),
    f"datasets/{encoder_id}_train_{project_name}.tar",
)

# %%
create_webdataset(
    create_training_samples(df_val),
    f"datasets/{encoder_id}_val_{project_name}.tar",
)

# %%
create_webdataset(
    create_training_samples(df_test),
    f"datasets/{encoder_id}_test_{project_name}.tar",
)

# %% [markdown]
# ### Training

# %%
import os

import numpy as np
import torch
from cavmir.training.dataset import create_dataloader_from_webdataset_path
from cavmir.training.fit import fit_cav_model
from cavmir.training.network import CAVNetwork

# %%
train_dataloader = create_dataloader_from_webdataset_path(
    f"datasets/{encoder_id}_train_{project_name}.tar", batch_size=batch_size
)

val_dataloader = create_dataloader_from_webdataset_path(
    f"datasets/{encoder_id}_val_{project_name}.tar", batch_size=batch_size
)

model = CAVNetwork(
    input_shape=embedding_dim,
    target_shape=1,
    dropout_rate=dropout_rate,
)
# Out:
# /home/arne/Documents/git/CAV-MIR/.venv/lib/python3.12/site-packages/webdataset/compat.py:389: UserWarning: WebDataset(shardshuffle=...) is None; set explicitly to False or a number
#   warnings.warn(

# %%
# %%time

fit_cav_model(
    model,
    train_dataloader,
    val_dataloader,
    f"trainings/{project_name}/",
    num_epochs=epochs,
    learning_rate=learning_rate,
)
# Out:
# Epoch 1/1000
# Epoch 1 Train Loss: 0.6933
# Epoch 1 Validation Loss: 0.6935
# Model saved to trainings/singer_age_decade_30/state_dict.pth
# Epoch 2/1000
# Epoch 2 Train Loss: 0.6863
# Epoch 2 Validation Loss: 0.6910
# Model saved to trainings/singer_age_decade_30/state_dict.pth
# Epoch 3/1000
# Epoch 3 Train Loss: 0.6830
# Epoch 3 Validation Loss: 0.6902
# Model saved to trainings/singer_age_decade_30/state_dict.pth
# Epoch 4/1000
# Epoch 4 Train Loss: 0.6803
# Epoch 4 Validation Loss: 0.6892
# Model saved to trainings/singer_age_decade_30/state_dict.pth
# Epoch 5/1000
# Epoch 5 Train Loss: 0.6781
# Epoch 5 Validation Loss: 0.6889
# Model saved to trainings/singer_age_decade_30/state_dict.pth
# Epoch 6/1000
# Epoch 6 Train Loss: 0.6758
# Epoch 6 Validation Loss: 0.6886
# Model saved to trainings/singer_age_decade_30/state_dict.pth
# Epoch 7/1000
# Epoch 7 Train Loss: 0.6734
# Epoch 7 Validation Loss: 0.6886
# Model saved to trainings/singer_age_decade_30/state_dict.pth
# Epoch 8/1000
# Epoch 8 Train Loss: 0.6724
# Epoch 8 Validation Loss: 0.6886
# Epoch 9/1000
# Epoch 9 Train Loss: 0.6709
# Epoch 9 Validation Loss: 0.6879
# Model saved to trainings/singer_age_decade_30/state_dict.pth
# Epoch 10/1000
# Epoch 10 Train Loss: 0.6688
# Epoch 10 Validation Loss: 0.6878
# Model saved to trainings/singer_age_decade_30/state_dict.pth
# Epoch 11/1000
# Epoch 11 Train Loss: 0.6680
# Epoch 11 Validation Loss: 0.6876
# Model saved to trainings/singer_age_decade_30/state_dict.pth
# Epoch 12/1000
# Epoch 12 Train Loss: 0.6660
# Epoch 12 Validation Loss: 0.6877
# Epoch 13/1000
# Epoch 13 Train Loss: 0.6649
# Epoch 13 Validation Loss: 0.6874
# Model saved to trainings/singer_age_decade_30/state_dict.pth
# Epoch 14/1000
# Epoch 14 Train Loss: 0.6642
# Epoch 14 Validation Loss: 0.6873
# Model saved to trainings/singer_age_decade_30/state_dict.pth
# Epoch 15/1000
# Epoch 15 Train Loss: 0.6636
# Epoch 15 Validation Loss: 0.6873
# Model saved to trainings/singer_age_decade_30/state_dict.pth
# Epoch 16/1000
# Epoch 16 Train Loss: 0.6618
# Epoch 16 Validation Loss: 0.6868
# Model saved to trainings/singer_age_decade_30/state_dict.pth
# Epoch 17/1000
# Epoch 17 Train Loss: 0.6607
# Epoch 17 Validation Loss: 0.6872
# Epoch 18/1000
# Epoch 18 Train Loss: 0.6610
# Epoch 18 Validation Loss: 0.6867
# Model saved to trainings/singer_age_decade_30/state_dict.pth
# Epoch 19/1000
# Epoch 19 Train Loss: 0.6577
# Epoch 19 Validation Loss: 0.6872
# Epoch 20/1000
# Epoch 20 Train Loss: 0.6579
# Epoch 20 Validation Loss: 0.6872
# Epoch 21/1000
# Epoch 21 Train Loss: 0.6567
# Epoch 21 Validation Loss: 0.6872
# Epoch 22/1000
# Epoch 22 Train Loss: 0.6560
# Epoch 22 Validation Loss: 0.6871
# Epoch 23/1000
# Epoch 23 Train Loss: 0.6558
# Epoch 23 Validation Loss: 0.6871
# Early stopping at epoch 23
# Loss history saved to trainings/singer_age_decade_30/loss_history.json
# CPU times: user 3.19 s, sys: 2.25 s, total: 5.44 s
# Wall time: 59.2 s

# %%
model.load_state_dict(
    torch.load(
        os.path.join(
            "trainings",
            project_name,
            "state_dict.pth",
        )
    )
)

cav_vector = model.get_concept_activation_vector()


np.save(
    os.path.join(
        "trainings",
        project_name,
        f"cav_{project_name}.npy",
    ),
    cav_vector,
)

# %% [markdown]
# ### Evaluation

# %%
import json

import matplotlib.pyplot as plt
from cavmir.training.evaluate import evaluate_cav_model

# %%
loss_history = json.load(open(f"trainings/{project_name}/loss_history.json"))

plt.plot(loss_history["train_loss"], label="train")
plt.plot(loss_history["val_loss"], label="val")
plt.legend()
plt.grid()
plt.show()

# %%
test_dataloader = create_dataloader_from_webdataset_path(
    f"datasets/{encoder_id}_test_{project_name}.tar", batch_size=batch_size
)

evaluate_cav_model(model, test_dataloader, target_positive_class)
# Out:
# {'precision': 0.5584299732381802,
#  'recall': 0.5467248908296943,
#  'f1_score': 0.5525154457193292,
#  'accuracy': 0.5572052401746724}
