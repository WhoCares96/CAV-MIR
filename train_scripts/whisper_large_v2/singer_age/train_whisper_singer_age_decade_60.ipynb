# %% [markdown]
# ### Prerequisites

# %%
import dotenv

dotenv.load_dotenv()
# Out:
# True

# %%
project_name = "singer_age_decade_60"
encoder_id = "whisper_large_v2"

# data preparation
target_column = "singer_age_decade"
target_positive_class = 60
train_val_split = 0.9


# training
epochs = 1000
batch_size = 128
learning_rate = 0.002
embedding_dim = 1280
dropout_rate = 0.0

# %% [markdown]
# ### Prepare Data

# %%
import io
import os
from concurrent.futures import ThreadPoolExecutor

import numpy as np
import pandas as pd
import s3fs
from cavmir.training.dataset import TrainingSample, create_webdataset

s3 = s3fs.S3FileSystem(anon=False)

dataset_prefix = os.environ["DATASET_PREFIX"]
embedding_prefix = os.environ["EMBEDDING_PREFIX"]


def create_embedding_path(song_id: str) -> str:
    return os.path.join(embedding_prefix, encoder_id, f"{song_id}.{encoder_id}.npy")


def create_training_sample(
    row: pd.Series, target_column: str, target_positive_class: str
) -> TrainingSample:
    embedding_path = create_embedding_path(row.song_id)
    embedding = np.load(io.BytesIO(s3.cat(embedding_path)))[0]

    target = np.array(
        [1] if getattr(row, target_column) == target_positive_class else [0]
    )

    training_sample = TrainingSample(
        id=str(row.song_id),
        embedding=embedding,
        target=target,
    )

    training_sample.validate_attributes()

    return training_sample


def create_training_samples(dataset: pd.DataFrame) -> list[TrainingSample]:
    with ThreadPoolExecutor() as executor:
        return list(
            executor.map(
                lambda row: create_training_sample(
                    row, target_column, target_positive_class
                ),
                dataset.itertuples(),
            )
        )

# %%
df = pd.read_csv(os.path.join(dataset_prefix, f"train_dataset_{project_name}.csv"))
df = df.sample(frac=1, random_state=1).reset_index(drop=True)

df_train = df.iloc[: int(len(df) * train_val_split)]
df_val = df.iloc[int(len(df) * train_val_split) :]

df_test = pd.read_csv(os.path.join(dataset_prefix, f"test_dataset_{project_name}.csv"))

# %%
create_webdataset(
    create_training_samples(df_train),
    f"datasets/{encoder_id}_train_{project_name}.tar",
)

# %%
create_webdataset(
    create_training_samples(df_val),
    f"datasets/{encoder_id}_val_{project_name}.tar",
)

# %%
create_webdataset(
    create_training_samples(df_test),
    f"datasets/{encoder_id}_test_{project_name}.tar",
)

# %% [markdown]
# ### Training

# %%
import os

import numpy as np
import torch
from cavmir.training.dataset import create_dataloader_from_webdataset_path
from cavmir.training.fit import fit_cav_model
from cavmir.training.network import CAVNetwork

# %%
train_dataloader = create_dataloader_from_webdataset_path(
    f"datasets/{encoder_id}_train_{project_name}.tar", batch_size=batch_size
)

val_dataloader = create_dataloader_from_webdataset_path(
    f"datasets/{encoder_id}_val_{project_name}.tar", batch_size=batch_size
)

model = CAVNetwork(
    input_shape=embedding_dim,
    target_shape=1,
    dropout_rate=dropout_rate,
)
# Out:
# /home/arne/Documents/git/CAV-MIR/.venv/lib/python3.12/site-packages/webdataset/compat.py:389: UserWarning: WebDataset(shardshuffle=...) is None; set explicitly to False or a number
#   warnings.warn(

# %%
# %%time

fit_cav_model(
    model,
    train_dataloader,
    val_dataloader,
    f"trainings/{project_name}/",
    num_epochs=epochs,
    learning_rate=learning_rate,
)
# Out:
# Epoch 1/1000
# Epoch 1 Train Loss: 0.6881
# Epoch 1 Validation Loss: 0.6793
# Model saved to trainings/singer_age_decade_60/state_dict.pth
# Epoch
# Model saved to trainings/singer_age_decade_60/state_dict.pth
# Epoch 34/1000
# Epoch 34 Train Loss: 0.5344
# Epoch 34 Validation Loss: 0.6234
# Model saved to trainings/singer_age_decade_60/state_dict.pth
# Epoch 35/1000
# Epoch 35 Train Loss: 0.5322
# Epoch 35 Validation Loss: 0.6233
# Model saved to trainings/singer_age_decade_60/state_dict.pth
# Epoch 36/1000
# Epoch 36 Train Loss: 0.5301
# Epoch 36 Validation Loss: 0.6232
# Model saved to trainings/singer_age_decade_60/state_dict.pth
# Epoch 37/1000
# Epoch 37 Train Loss: 0.5280
# Epoch 37 Validation Loss: 0.6230
# Model saved to trainings/singer_age_decade_60/state_dict.pth
# Epoch 38/1000
# Epoch 38 Train Loss: 0.5259
# Epoch 38 Validation Loss: 0.6229
# Model saved to trainings/singer_age_decade_60/state_dict.pth
# Epoch 39/1000
# Epoch 39 Train Loss: 0.5239
# Epoch 39 Validation Loss: 0.6228
# Model saved to trainings/singer_age_decade_60/state_dict.pth
# Epoch 40/1000
# Epoch 40 Train Loss: 0.5219
# Epoch 40 Validation Loss: 0.6228
# Model saved to trainings/singer_age_decade_60/state_dict.pth
# Epoch 41/1000
# Epoch 41 Train Loss: 0.5200
# Epoch 41 Validation Loss: 0.6227
# Model saved to trainings/singer_age_decade_60/state_dict.pth
# Epoch 42/1000
# Epoch 42 Train Loss: 0.5181
# Epoch 42 Validation Loss: 0.6227
# Model saved to trainings/singer_age_decade_60/state_dict.pth
# Epoch 43/1000
# Epoch 43 Train Loss: 0.5162
# Epoch 43 Validation Loss: 0.6226
# Model saved to trainings/singer_age_decade_60/state_dict.pth
# Epoch 44/1000
# Epoch 44 Train Loss: 0.5144
# Epoch 44 Validation Loss: 0.6226
# Model saved to trainings/singer_age_decade_60/state_dict.pth
# Epoch 45/1000
# Epoch 45 Train Loss: 0.5126
# Epoch 45 Validation Loss: 0.6226
# Model saved to trainings/singer_age_decade_60/state_dict.pth
# Epoch 46/1000
# Epoch 46 Train Loss: 0.5108
# Epoch 46 Validation Loss: 0.6226
# Model saved to trainings/singer_age_decade_60/state_dict.pth
# Epoch 47/1000
# Epoch 47 Train Loss: 0.5090
# Epoch 47 Validation Loss: 0.6226
# Epoch 48/1000
# Epoch 48 Train Loss: 0.5073
# Epoch 48 Validation Loss: 0.6226
# Epoch 49/1000
# Epoch 49 Train Loss: 0.5056
# Epoch 49 Validation Loss: 0.6227
# Epoch 50/1000
# Epoch 50 Train Loss: 0.5043
# Epoch 50 Validation Loss: 0.6226
# Epoch 51/1000
# Epoch 51 Train Loss: 0.5042
# Epoch 51 Validation Loss: 0.6226
# Early stopping at epoch 51
# Loss history saved to trainings/singer_age_decade_60/loss_history.json
# CPU times: user 2.1 s, sys: 3.86 s, total: 5.95 s
# Wall time: 46 s

# %%
model.load_state_dict(
    torch.load(
        os.path.join(
            "trainings",
            project_name,
            "state_dict.pth",
        )
    )
)

cav_vector = model.get_concept_activation_vector()


np.save(
    os.path.join(
        "trainings",
        project_name,
        f"cav_{project_name}.npy",
    ),
    cav_vector,
)

# %% [markdown]
# ### Evaluation

# %%
import json

import matplotlib.pyplot as plt
from cavmir.training.evaluate import evaluate_cav_model

# %%
loss_history = json.load(open(f"trainings/{project_name}/loss_history.json"))

plt.plot(loss_history["train_loss"], label="train")
plt.plot(loss_history["val_loss"], label="val")
plt.legend()
plt.grid()
plt.show()

# %%
test_dataloader = create_dataloader_from_webdataset_path(
    f"datasets/{encoder_id}_test_{project_name}.tar", batch_size=batch_size
)

evaluate_cav_model(model, test_dataloader, target_positive_class)
# Out:
# /home/arne/Documents/git/CAV-MIR/.venv/lib/python3.12/site-packages/webdataset/compat.py:389: UserWarning: WebDataset(shardshuffle=...) is None; set explicitly to False or a number
#   warnings.warn(
# {'precision': 0.6309523809523809,
#  'recall': 0.6708860759493671,
#  'f1_score': 0.6503067484662577,
#  'accuracy': 0.6392405063291139}
